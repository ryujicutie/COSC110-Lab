# %% [markdown]
# # Laboratory Activity #1: Computational Thinking with the Titanic Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Question 1:

# %%
import pandas as pd

df = pd.read_csv("titanic.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Importing necessary libaries like pandas, then read the csv file using pd.read_csv("titanic.csv")., and display the first few rows using df.head().

# %% [markdown]
# ## Question 2:

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Collumns that contain missing values are: Age, Cabin, Embarked.
#
# The Age column should be filled with the mean and Cabin could be filled with "Unknown" or dropped if not useful.

# %% [markdown]
# ## Question 3:

# %%
df["Survived"].mean()
# Out:
# 0.3838383838383838

# %% [markdown]
# The survival rate lies at 38% which indicates a result that higher classes with female passengers had the highest survival rate. Based on the gathered data we can assume that the upper classes had a different exit route for them to escape faster, higher quality of rooms, and prioritized due to their status or classes. We can clearly see the notable differences when comparing the upper class to the economic class.

# %%
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# ## Question 4:

# %%
import matplotlib.pyplot as plt
# Plot age distribution of survivors vs. non-survivors
plt.hist(df[df["Survived"] == 1]["Age"].dropna(), bins=20, alpha=0.5, label="Survived")
plt.hist(df[df["Survived"] == 0]["Age"].dropna(), bins=20, alpha=0.5, label="Did Not Survive")
plt.legend()
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Historical survival statistics demonstrate that passengers below thirty years old achieved better survival because emergency crews gave them first priority during rescue operations. The elderly people aboard had worse survival rates especially among those who maintained third-class accommodations. The analysis of data will show if the survival pattern between different age groups exists within the particular dataset.

# %%
average_age = df.groupby("Survived")["Age"].mean()
print(average_age)
# Out:
# Survived
# 0    30.415100
# 1    28.549778
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt
df[df["Survived"] == 1]["Age"].hist(alpha=0.5, color="blue", label="Survived")
df[df["Survived"] == 0]["Age"].hist(alpha=0.5, color="red", label="Did not survive")
plt.xlabel("Age")
plt.ylabel("Count")
plt.legend()
plt.title("Age Distribution of Survivors vs. Non-Survivors")
plt.show()
