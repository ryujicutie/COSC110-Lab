# %% [markdown]
# # Exploring Calculus with SymPy
#
# ## Activity Instructions
# This activity is designed to help you explore how Python can be used to understand basic ideas in calculus — without needing to do any complex math.
#
# Use the Python code snippets provided to experiment and answer the questions.

# %%
from sympy import *

# %% [markdown]
# ---
# ## Playing with Symbols
#
# Try running this code:

# %%
x = symbols('x')
x + x
# Out:
# 2*x

# %% [markdown]
# **1. What do you think 'x + x' means?** (Answers below)

# %% [markdown]
# It simplifies to 2*x. This represents adding the variable x to itself, or 1x + 1x = 2x.

# %% [markdown]
# Now try this:

# %%
x * x
# Out:
# x**2

# %% [markdown]
# **2. What does `x * x` represent?** (Answers below)

# %% [markdown]
# This means you're multiplying x by itself, or x × x = x^2

# %% [markdown]
# ---
# ## Exploring Limits
#
# Try this code:

# %%
limit(sin(x)/x, x, 0)
# Out:
# 1

# %% [markdown]
# **3. What result do you get? What do you think it means?** (Answers below)

# %% [markdown]
# You can’t just plug in x = 0 because that gives you 0/0 — which doesn’t make sense. But math has a clever tool called a limit, which helps us figure out what the value is approaching. The closer x gets to 0, the closer sin(x)/x gets to 1.

# %% [markdown]
# ---
# ## Playing with Derivatives
#
# Run this:

# %%
diff(x**2, x)
# Out:
# 2*x

# %% [markdown]
# **4. What is the output? Can you describe what it tells you?** (Answers below)

# %% [markdown]
# This tells you the derivative of x^2 with respect to x. In simple terms:
#
# It tells you how fast x^2 is changing as x changes. So the bigger x gets, the faster x^2 grows and 2x tells you exactly how fast.

# %% [markdown]
# ---
#
# ## 4. Series Expansion
#
# Run this code:

# %%
exp(x).series(x, 0, 4)
# Out:
# 1 + x + x**2/2 + x**3/6 + O(x**4)

# %% [markdown]
# **5. What do you see? How many terms are shown in the result?**  (Answers below)

# %% [markdown]
# There are 4 main terms shown:
#
# 1
#
# x
#
# x^2/2
#
# x^3/6
#
# The O(x^4) at the end means “there are more terms that involve x^4 and beyond, but we’re stopping here.”

# %% [markdown]
# ---
#
# ## 5. Solving Equations
#
# Try solving this equation:

# %%
solve(Eq(x**2 - 4, 0), x)
# Out:
# [-2, 2]

# %% [markdown]
# **6. What are the answers?** (Answer below)

# %% [markdown]
# x = -2 and x = 2

# %% [markdown]
# **7. What kind of problem do you think this is?** (Answer below)

# %% [markdown]
# This is a quadratic equation problem. It involves x^2, so it’s a second-degree equation.

# %% [markdown]
# ---
#
# ## 6. Final Thoughts
#
# **8. What was your favorite part of this activity?** (Answer below)

# %% [markdown]
# My favorite part was seeing how Python (with SymPy) can do calculus for me,especially finding derivatives and solving equations so quickly. It made hard math feel easier and more fun to explore.

# %% [markdown]
# **9. What was something new or surprising you learned?**  (Answer below)

# %% [markdown]
# I was surprised to learn that functions like 𝑒^𝑥 can be written as a series of simple terms using powers of x. I didn’t know calculators use this idea to estimate values. It made me realize that math is full of clever shortcuts!
